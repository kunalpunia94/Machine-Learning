# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Machine Learning 100 days\Day_74_Naive_bayes\play_tennis.csv")

# %%
df.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
df.drop(columns=['day'],inplace=True)

# %%
df.head()
# Out:
#     outlook  temp humidity    wind play
# 0     Sunny   Hot     High    Weak   No
# 1     Sunny   Hot     High  Strong   No
# 2  Overcast   Hot     High    Weak  Yes
# 3      Rain  Mild     High    Weak  Yes
# 4      Rain  Cool   Normal    Weak  Yes

# %%
#Problem 1

#outlook=sunny, temp=hot, humidity=high, wind=weak
#play or not play?

# %%
#solution 1

#P(Yes | sunny,hot,high,weak)=P(sunny | yes) * P(hot | yes) * P(high | yes) * P(weak | yes) * P(yes)
#P(No | sunny,hot,high,weak)=P(sunny | no) * P(hot | no) * P(high | no) * P(weak | no) * P(no)

#compare and decide using the maximum a posterios rule

# %%
#Problem 2

#outlook=overcast, temp=cold, humidity=low, wind=weak
#play or not play?

# %%
#solution 2

# change accordingly

#compare and decide using the maximum a posterios rule

# %%
#Any machine learning algorithm works in two phases training and testing phase

#so in training state Naive bayes creates a loopup table and stores in dictionary like stores all the possible possiblities

# %%
#let's find probability 

#P(Yes)
#P(No)

# %%
df['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
pyes = 9/14
pno = 5/14

# %%
print(pyes)
print(pno)
# Out:
# 0.6428571428571429
# 0.35714285714285715

# %%
#Outlook column
pd.crosstab(df['outlook'],df['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
POvercastNo=0
PRainNo=2/5
PSunnyNo=3/5

POvercastYes=4/9
PRainYes=3/9
PSunnyYes=2/9

# %%
#temp column
pd.crosstab(df['temp'],df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
PCoolNo=1/5
PHotNo=2/5
PMildNo=2/5

PCoolYes=3/9
PHotYes=2/9
PMildYes=4/9

# %%
#humidity column
pd.crosstab(df['humidity'],df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
PHighNo=4/5
PNormalNo=1/5

PHighYes=3/9
PNormalYes=6/9

# %%
#wind column
pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
PStrongNo=3/5
PWeakNo=2/5

PStringYes=3/9
PWeakYes=6/9
#till here our look up table is ready

# %%
#outlook=sunny, temp=hot, humidity=high, wind=weak
#play or not play?
PPlay = pyes * PSunnyYes * PHotYes * PHighYes * PWeakYes
print(PPlay)

PNotPlay = pno * PSunnyNo * PHotNo * PHighNo * PWeakNo
print(PNotPlay)
# Out:
# 0.007054673721340388
# 0.02742857142857143

# %%
#so this will not play bcoz it have the more probability
